# %% [markdown]
# #Document retrieval from wikipedia data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import zipfile

local_zip = '/content/gdrive/My Drive/Public/people-wikipedia-data.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('')
zip_ref.close()

# %%
import pandas as pd

# %% [markdown]
# #Load some text data - from wikipedia, pages on people

# %%
data_source = "people_wiki.csv"
people = pd.read_csv(open(data_source, 'r', encoding='utf8'), delimiter=',')

# %% [markdown]
# Data contains:  link to wikipedia article, name of person, text of article.

# %%
people.head()
# Out:
#                                                  URI  ...                                               text
# 0        <http://dbpedia.org/resource/Digby_Morrell>  ...  digby morrell born 10 october 1979 is a former...
# 1       <http://dbpedia.org/resource/Alfred_J._Lewy>  ...  alfred j lewy aka sandy lewy graduated from un...
# 2        <http://dbpedia.org/resource/Harpdog_Brown>  ...  harpdog brown is a singer and harmonica player...
# 3  <http://dbpedia.org/resource/Franz_Rottensteiner>  ...  franz rottensteiner born in waidmannsfeld lowe...
# 4               <http://dbpedia.org/resource/G-Enka>  ...  henry krvits born 30 december 1974 in tallinn ...
#
# [5 rows x 3 columns]

# %%
len(people)
# Out:
# 42786

# %% [markdown]
# #Explore the dataset and checkout the text it contains
#
# ##Exploring the entry for president Obama

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
obama.iloc[0]['text']
# Out:
# 'barack hussein obama ii brk husen bm born august 4 1961 is the 44th and current president of the united states and the first african american to hold the office born in honolulu hawaii obama is a graduate of columbia university and harvard law school where he served as president of the harvard law review he was a community organizer in chicago before earning his law degree he worked as a civil rights attorney and taught constitutional law at the university of chicago law school from 1992 to 2004 he served three terms representing the 13th district in the illinois senate from 1997 to 2004 running unsuccessfully for the united states house of representatives in 2000in 2004 obama received national attention during his campaign to represent illinois in the united states senate with his victory in the march democratic party primary his keynote address at the democratic national convention in july and his election to the senate in november he began his presidential campaign in 2007 and af
# ...

# %%
obama
# Out:
#                                               URI  ...                                               text
# 35811  <http://dbpedia.org/resource/Barack_Obama>  ...  barack hussein obama ii brk husen bm born augu...
#
# [1 rows x 3 columns]

# %%
obama.loc[35811]['text']
# Out:
# 'barack hussein obama ii brk husen bm born august 4 1961 is the 44th and current president of the united states and the first african american to hold the office born in honolulu hawaii obama is a graduate of columbia university and harvard law school where he served as president of the harvard law review he was a community organizer in chicago before earning his law degree he worked as a civil rights attorney and taught constitutional law at the university of chicago law school from 1992 to 2004 he served three terms representing the 13th district in the illinois senate from 1997 to 2004 running unsuccessfully for the united states house of representatives in 2000in 2004 obama received national attention during his campaign to represent illinois in the united states senate with his victory in the march democratic party primary his keynote address at the democratic national convention in july and his election to the senate in november he began his presidential campaign in 2007 and af
# ...

# %% [markdown]
# ##Exploring the entry for actor George Clooney

# %%
clooney = people[people['name'] == 'George Clooney']
clooney.iloc[0]['text']
# Out:
# 'george timothy clooney born may 6 1961 is an american actor writer producer director and activist he has received three golden globe awards for his work as an actor and two academy awards one for acting and the other for producingclooney made his acting debut on television in 1978 and later gained wide recognition in his role as dr doug ross on the longrunning medical drama er from 1994 to 1999 for which he received two emmy award nominations while working on er he began attracting a variety of leading roles in films including the superhero film batman robin 1997 and the crime comedy out of sight 1998 in which he first worked with a director who would become a longtime collaborator steven soderbergh in 1999 clooney took the lead role in three kings a wellreceived war satire set during the gulf warin 2001 clooneys fame widened with the release of his biggest commercial success the heist comedy oceans eleven the first of the film trilogy a remake of the 1960 film with frank sinatra as
# ...

# %% [markdown]
# #Get the word counts for Obama article

# %%
from collections import Counter

# %%
obama_word_count = Counter(obama.iloc[0]['text'].split())
print(obama_word_count)
# Out:
# Counter({'the': 40, 'in': 30, 'and': 21, 'of': 18, 'to': 14, 'his': 11, 'obama': 9, 'act': 8, 'a': 7, 'he': 7, 'law': 6, 'as': 6, 'us': 6, 'was': 5, 'president': 4, 'for': 4, 'democratic': 4, 'after': 4, 'military': 4, 'iraq': 4, 'control': 4, 'has': 4, 'united': 3, 'states': 3, 'first': 3, 'american': 3, 'school': 3, 'from': 3, '2004': 3, 'senate': 3, 'campaign': 3, 'with': 3, 'party': 3, 'election': 3, 'january': 3, '2009': 3, 'signed': 3, 'response': 3, 'term': 3, 'involvement': 3, 'ordered': 3, '2011': 3, 'born': 2, 'is': 2, 'office': 2, 'university': 2, 'harvard': 2, 'served': 2, 'chicago': 2, 'at': 2, 'illinois': 2, 'house': 2, 'representatives': 2, 'national': 2, 'during': 2, 'primary': 2, 'november': 2, 'presidential': 2, 'republican': 2, 'nominee': 2, 'on': 2, '20': 2, 'relief': 2, '2010': 2, 'domestic': 2, 'protection': 2, 'dont': 2, 'foreign': 2, 'policy': 2, 'afghanistan': 2, 'second': 2, 'barack': 1, 'hussein': 1, 'ii': 1, 'brk': 1, 'husen': 1, 'bm': 1, 'august': 1, '4':
# ...

# %% [markdown]
# ##Sort the word counts for the Obama article

# %% [markdown]
# Most common words include uninformative words like "the", "in", "and",...

# %% [markdown]
# #Compute TF-IDF for the corpus
#
# To give more weight to informative words, we weigh them by their TF-IDF scores.

# %%
people['word_count'] = people['text'].apply(lambda x: Counter(x.split()))
people.head()
# Out:
#                                                  URI  ...                                         word_count
# 0        <http://dbpedia.org/resource/Digby_Morrell>  ...  {'digby': 1, 'morrell': 5, 'born': 1, '10': 1,...
# 1       <http://dbpedia.org/resource/Alfred_J._Lewy>  ...  {'alfred': 1, 'j': 1, 'lewy': 3, 'aka': 1, 'sa...
# 2        <http://dbpedia.org/resource/Harpdog_Brown>  ...  {'harpdog': 2, 'brown': 2, 'is': 7, 'a': 7, 's...
# 3  <http://dbpedia.org/resource/Franz_Rottensteiner>  ...  {'franz': 1, 'rottensteiner': 3, 'born': 1, 'i...
# 4               <http://dbpedia.org/resource/G-Enka>  ...  {'henry': 1, 'krvits': 1, 'born': 1, '30': 1, ...
#
# [5 rows x 4 columns]

# %%
tfidf = graphlab.text_analytics.tf_idf(people['word_count'])
tfidf
# Out:
# Columns:
# 	docs	dict
#
# Rows: 59071
#
# Data:
# +-------------------------------+
# |              docs             |
# +-------------------------------+
# | {'since': 1.45537671730804... |
# | {'precise': 6.443200606955... |
# | {'just': 2.700729968710864... |
# | {'all': 1.6431112434912472... |
# | {'legendary': 4.2808562943... |
# | {'now': 1.96695239252401, ... |
# | {'exclusive': 10.455187230... |
# | {'taxi': 6.052021456094502... |
# | {'houston': 3.935505942157... |
# | {'phenomenon': 5.750053426... |
# +-------------------------------+
# [59071 rows x 1 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
people['tfidf'] = tfidf['docs']

# %% [markdown]
# ##Examine the TF-IDF for the Obama article

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
obama[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 273
#
# Data:
# +-------------+---------------+
# |     word    |     tfidf     |
# +-------------+---------------+
# |    obama    | 43.2956530721 |
# |     act     |  27.678222623 |
# |     iraq    |  17.747378588 |
# |   control   | 14.8870608452 |
# |     law     | 14.7229357618 |
# |   ordered   | 14.5333739509 |
# |   military  | 13.1159327785 |
# | involvement | 12.7843852412 |
# |   response  | 12.7843852412 |
# |  democratic | 12.4106886973 |
# +-------------+---------------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Words with highest TF-IDF are much more informative.

# %% [markdown]
# #Manually compute distances between a few people
#
# Let's manually compare the distances between the articles for a few famous people.

# %%
clinton = people[people['name'] == 'Bill Clinton']

# %%
beckham = people[people['name'] == 'David Beckham']

# %% [markdown]
# ##Is Obama closer to Clinton than to Beckham?
#
# We will use cosine distance, which is given by
#
# (1-cosine_similarity)
#
# and find that the article about president Obama is closer to the one about former president Clinton than that of footballer David Beckham.

# %%
graphlab.distances.cosine(obama['tfidf'][0],clinton['tfidf'][0])
# Out:
# 0.8339854936884276

# %%
graphlab.distances.cosine(obama['tfidf'][0],beckham['tfidf'][0])
# Out:
# 0.9791305844747478

# %% [markdown]
# #Build a nearest neighbor model for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_model = graphlab.nearest_neighbors.create(people,features=['tfidf'],label='name')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %% [markdown]
# #Applying the nearest-neighbors model for retrieval

# %% [markdown]
# ##Who is closest to Obama?

# %%
knn_model.query(obama)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 18.87ms      |
# PROGRESS: | Done         |         | 100         | 194.698ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |   Barack Obama  |      0.0       |  1   |
# |      0      |    Joe Biden    | 0.794117647059 |  2   |
# |      0      |  Joe Lieberman  | 0.794685990338 |  3   |
# |      0      |   Kelly Ayotte  | 0.811989100817 |  4   |
# ...

# %% [markdown]
# As we can see, president Obama's article is closest to the one about his vice-president Biden, and those of other politicians.

# %% [markdown]
# ##Other examples of document retrieval

# %%
swift = people[people['name'] == 'Taylor Swift']

# %%
knn_model.query(swift)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 17.804ms     |
# PROGRESS: | Done         |         | 100         | 135.698ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+----------------+------+
# | query_label | reference_label  |    distance    | rank |
# +-------------+------------------+----------------+------+
# |      0      |   Taylor Swift   |      0.0       |  1   |
# |      0      | Carrie Underwood | 0.76231884058  |  2   |
# |      0      |   Alicia Keys    | 0.764705882353 |  3   |
# |      0      |  Jordin Sparks   | 0.769633507853 |  4   |
# ...

# %%
jolie = people[people['name'] == 'Angelina Jolie']

# %%
knn_model.query(jolie)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 24.658ms     |
# PROGRESS: | Done         |         | 100         | 149.909ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------+----------------+------+
# | query_label |  reference_label   |    distance    | rank |
# +-------------+--------------------+----------------+------+
# |      0      |   Angelina Jolie   |      0.0       |  1   |
# |      0      |     Brad Pitt      | 0.784023668639 |  2   |
# |      0      |   Julianne Moore   | 0.795857988166 |  3   |
# |      0      | Billy Bob Thornton | 0.803069053708 |  4   |
# ...

# %%
arnold = people[people['name'] == 'Arnold Schwarzenegger']

# %%
knn_model.query(arnold)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 23.009ms     |
# PROGRESS: | Done         |         | 100         | 151.716ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------------+----------------+------+
# | query_label |    reference_label    |    distance    | rank |
# +-------------+-----------------------+----------------+------+
# |      0      | Arnold Schwarzenegger |      0.0       |  1   |
# |      0      |     Jesse Ventura     | 0.818918918919 |  2   |
# |      0      |     John Kitzhaber    | 0.824615384615 |  3   |
# ...
